# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smf
import statsmodels.formula.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-87303889-01e1-4b90-a426-831c5d8f32e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87303889-01e1-4b90-a426-831c5d8f32e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
d = pd.read_csv('delivery_time.csv')
d
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df = d.rename({'Delivery Time' : 'Delivery_Time','Sorting Time':'Sorting_Time'}, axis =1)
df
# Out:
#     Delivery_Time  Sorting_Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
d.info
# Out:
# <bound method DataFrame.info of     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5>

# %%
d.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
d.isnull().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
d[d.duplicated()].shape
# Out:
# (0, 2)

# %%
d[d.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Delivery Time, Sorting Time]
# Index: []

# %%
plt.subplots(figsize = (10,5))
plt.subplot(121)
plt.boxplot(d['Delivery Time'])
plt.title('Delivery Time')
plt.subplot(122)
plt.boxplot(d['Sorting Time'])
plt.title('Sorting Time')
plt.show()

# %%
d.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
sns.regplot(x=d['Sorting Time'],y=d['Delivery Time'])
# Out:
# <Axes: xlabel='Sorting Time', ylabel='Delivery Time'>

# %% [markdown]
# **Hence there is good co-relation between the two variables.**

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x = d['Sorting Time'], y = d['Delivery Time'])
plt.title('Hetroscedasticity', fontweight = 'bold', fontsize = 16)
plt.show()

# %%
d.var()
# Out:
# Delivery Time    25.754619
# Sorting Time      6.461905
# dtype: float64

# %%
sns.distplot(d['Delivery Time'], bins = 15, kde = True)
plt.title('Before Transformation')
sns.displot(np.log(d['Delivery Time']), bins = 15, kde = True)
plt.title("After Transformation")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
labels = ['Before Transformation','After Transformation']
sns.distplot(d['Delivery Time'], bins = 15, kde = True)
sns.distplot(np.log(d['Delivery Time']), bins = 15, kde = True)
plt.legend(labels)
plt.show()

# %%
smf.qqplot(d['Delivery Time'], line = 'r')
plt.title('No transformation')
smf.qqplot(np.log(d['Delivery Time']), line = 'r')
plt.title('long transforamtion')
smf.qqplot(np.sqrt(d['Delivery Time']), line = 'r')
plt.title('Square root transformation')
smf.qqplot(np.cbrt(d['Delivery Time']), line = 'r')
plt.title('Cube root transformation')
plt.show()

# %%
labels =  ['Before Transformation','After Transformation']
sns.displot(d['Sorting Time'], bins = 7, kde = True)
sns.displot(np.log(d['Sorting Time']), bins = 7, kde = True)
plt.legend(labels)
plt.show()

# %%
smf.qqplot(d['Sorting Time'], line = 'r')
plt.title('No transformation')
smf.qqplot(np.log(d['Sorting Time']), line = 'r')
plt.title('Log transformation')
smf.qqplot(np.sqrt(d['Sorting Time']), line = 'r')
plt.title('square root transformation')
smf.qqplot(np.cbrt(d['Sorting Time']), line = 'r')
plt.title('Cube root transformation')
plt.show()

# %% [markdown]
# Hence only perform any data transformation when the data is skewed or not normal.

# %%
model = sm.ols('Delivery_Time~Sorting_Time', data = df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Delivery_Time   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           3.98e-06
# Time:                        09:54:45   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# The R-Squared and Adjusted R-Squared scores are still below.

# %%
model1 = sm.ols('np.sqrt(Delivery_Time)~np.sqrt(Sorting_Time)', data = df).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     np.sqrt(Delivery_Time)   R-squared:                       0.729
# Model:                                OLS   Adj. R-squared:                  0.715
# Method:                     Least Squares   F-statistic:                     51.16
# Date:                    Fri, 28 Jul 2023   Prob (F-statistic):           8.48e-07
# Time:                            10:01:59   Log-Likelihood:                -5.7320
# No. Observations:                      21   AIC:                             15.46
# Df Residuals:                          19   BIC:                             17.55
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %%
model2 = sm.ols('np.cbrt(Delivery_Time)~np.cbrt(Sorting_Time)', data = df).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     np.cbrt(Delivery_Time)   R-squared:                       0.744
# Model:                                OLS   Adj. R-squared:                  0.731
# Method:                     Least Squares   F-statistic:                     55.25
# Date:                    Fri, 28 Jul 2023   Prob (F-statistic):           4.90e-07
# Time:                            10:02:20   Log-Likelihood:                 13.035
# No. Observations:                      21   AIC:                            -22.07
# Df Residuals:                          19   BIC:                            -19.98
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **~After Cueb root transformation on the Data, R-Squared and Ajusted R-Squared scores have increased but they are still below 0.85 which is a thumb rule we consider for a ood model for prediction.**

# %%
model3 = sm.ols('np.log(Delivery_Time)~np.log(Sorting_Time)', data = df).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     np.log(Delivery_Time)   R-squared:                       0.772
# Model:                               OLS   Adj. R-squared:                  0.760
# Method:                    Least Squares   F-statistic:                     64.39
# Date:                   Fri, 28 Jul 2023   Prob (F-statistic):           1.60e-07
# Time:                           10:04:55   Log-Likelihood:                 10.291
# No. Observations:                     21   AIC:                            -16.58
# Df Residuals:                         19   BIC:                            -14.49
# Df Model:                              1
# Covariance Type:               nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **~ After log transformtion on the Data, This Model has scored the highest R-Squared and Adjusted R-Squared scores than the previous model,Yet both Adjusted R-Squared and R-Squared Scores are still below 0.85 which is a thumb rule we consider for a good model for prediction.**

# %%
model.params
# Out:
# Intercept       6.582734
# Sorting_Time    1.649020
# dtype: float64

# %% [markdown]
# ~ Here, (Intercept) Beta0 value = 6.58 & (Sorting Time) Beta1 value = 1.64.
#
# ~ Hypothesis testing of X variable by finding test_statistics and P_values for Beta1 i.e if (P_value < α=0.05 ; Reject Null).
#
# ~ Null Hypothesis as Beta1=0 (No Slope) and Alternate Hypthesis as Beta1≠0 (Some or significant Slope).

# %%
print(model.tvalues, '\n',model.pvalues)
# Out:
# Intercept       3.823349
# Sorting_Time    6.387447
# dtype: float64
#  Intercept       0.001147
# Sorting_Time    0.000004
# dtype: float64

# %% [markdown]
# ~ (Intercept) Beta0: tvalue=3.82 , pvalue=0.001147.
#
# ~ As (pvalue=0)<(α=0.05); Reject Null hyp. Thus, X(Sorting Time) variable has good slope and variance w.r.t Y(Delivery Time) variable.
#
# ~ R-squared measures the strength of the relationship between your model and the dependent variable on a 0 – 100% scale.

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.6822714748417231, 0.6655489208860244)

# %% [markdown]
# **~Determination Co-efficient = rsquared value = 0.68;Very Good Fit>= 85%**

# %%
import statsmodels.api as sm
sm.qqplot(model.resid, line=  'q')
plt.title('Norma Q-Q plot of residuals of model without any data transformation')
plt.show()

# %%
sm.qqplot(model2.resid, line = 'q')
plt.title('Normal Q-Q plot of residuals of Model with Log transformation')
plt.show()

# %% [markdown]
# ~ Both The Model have slightly different plots.
#
# ~ The first model is right skewed and doesn't follow normal distribution.
#
# ~ The second model after log-transformation follows normal distributon with less skewness than first model.

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

plt.scatter(get_standardized_values(model.fittedvalues), get_standardized_values(model.resid))
plt.title('Residual Plot for Model without any data transformation')
plt.xlabel('Standardized Fitted Values')
plt.ylabel('Standardized Residual Values')
plt.show()

# %%
plt.scatter(get_standardized_values(model2.fittedvalues), get_standardized_values(model2.resid))
plt.title('Residual Plot for Model with Log transformation')
plt.xlabel('Standardized Features Values')
plt.ylabel('Standardized Residual Values')
plt.show()

# %% [markdown]
# ~ Both The Model have Homoscedasciticity.
#
# ~ The Residual(i.e Residual = Actual Value - Predicted Value) and the Fitted values do not share any Pattern.
#
# ~ Hence, there is no relation between the Residual and the Fitted Value. It is Randomly distributed.

# %%
from sklearn.metrics import mean_squared_error

# %%
model1_pred_y =np.square(model1.predict(df['Sorting_Time']))
model2_pred_y =pow(model2.predict(df['Sorting_Time']),3)
model3_pred_y =np.exp(model3.predict(df['Sorting_Time']))

# %%
model1_rmse =np.sqrt(mean_squared_error(df['Delivery_Time'], model1_pred_y))
model2_rmse =np.sqrt(mean_squared_error(df['Delivery_Time'], model2_pred_y))
model3_rmse =np.sqrt(mean_squared_error(df['Delivery_Time'], model3_pred_y))
print('model=', np.sqrt(model.mse_resid),'\n' 'model1=', model1_rmse,'\n' 'model2=', model2_rmse,'\n' 'model3=', model3_rmse)
# Out:
# model= 2.934903768890139
# model1= 2.762294279320867
# model2= 2.755584309893576
# model3= 2.745828897614548

# %%
data = {'model': np.sqrt(model.mse_resid), 'model1': model1_rmse, 'model2': model3_rmse, 'model3' : model3_rmse}
min(data, key=data.get)
# Out:
# 'model2'

# %% [markdown]
# **~ Model2 is the model where we did log transformation on both dependent variable as well as on independent variable**

# %%
pred = pd.DataFrame()
pred['Sorting_Time'] = df.Sorting_Time
pred['Delivery_Time'] = df.Delivery_Time
pred['Predicted_Delivery_Time'] = pd.DataFrame(np.exp(model2.predict(pred.Sorting_Time)))
pred
# Out:
#     Sorting_Time  Delivery_Time  Predicted_Delivery_Time
# 0             10          21.00                17.035997
# 1              4          13.50                10.547128
# 2              6          19.75                12.808396
# 3              9          24.00                15.997918
# 4             10          29.00                17.035997
# 5              6          15.35                12.808396
# 6              7          19.00                13.889274
# 7              3           9.50                 9.328887
# 8             10          17.90                17.035997
# 9              9          18.75                15.997918
# 10             8          19.83                14.950443
# 11             4          10.75                10.547128
# 12             7          16.68                13.889274
# 13             3          11.50                 9.328887
# 14             3          12.03                 9.328887
# ...

# %% [markdown]
# **Predicitng from Original Model without any data transformation**

# %%
pred1 = pd.DataFrame()
pred1['Sorting_Time'] = df.Sorting_Time
pred1['Delivery_Time'] = df.Delivery_Time
pred1['Predicted_Delivery_Time'] = pd.DataFrame(model.predict(pred1.Sorting_Time))
pred1
# Out:
#     Sorting_Time  Delivery_Time  Predicted_Delivery_Time
# 0             10          21.00                23.072933
# 1              4          13.50                13.178814
# 2              6          19.75                16.476853
# 3              9          24.00                21.423913
# 4             10          29.00                23.072933
# 5              6          15.35                16.476853
# 6              7          19.00                18.125873
# 7              3           9.50                11.529794
# 8             10          17.90                23.072933
# 9              9          18.75                21.423913
# 10             8          19.83                19.774893
# 11             4          10.75                13.178814
# 12             7          16.68                18.125873
# 13             3          11.50                11.529794
# 14             3          12.03                11.529794
# ...
