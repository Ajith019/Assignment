# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as smf
import statsmodels.formula.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ab09010-d905-4a00-b520-f86007c4f50e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6ab09010-d905-4a00-b520-f86007c4f50e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
sd = pd.read_csv('Salary_Data.csv')
sd
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sd.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
sd.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
sd[sd.duplicated()].shape
# Out:
# (0, 2)

# %%
plt.subplots(figsize = (10,5))
plt.subplot(121)
plt.boxplot(sd['Salary'])
plt.title('Salary Hike')
plt.subplot(122)
plt.boxplot(sd['YearsExperience'])
plt.title('Years of Experience')
plt.show()

# %%
sd.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.regplot(x=sd['YearsExperience'],y=sd['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# **There is good co-relation between the two variable.**

# %%
plt.figure(figsize = (10,8))
sns.scatterplot(x = sd['YearsExperience'], y = sd['Salary'])
plt.title('Homoscedasticity', fontweight = 'bold', fontsize = 16)
plt.show()

# %%
sd.var()
# Out:
# YearsExperience    8.053609e+00
# Salary             7.515510e+08
# dtype: float64

# %%
sns.distplot(sd['YearsExperience'], bins = 15, kde = True)
plt.title('Before Transformation')
sns.displot(np.log(sd['YearsExperience']), bins = 15, kde = True)
plt.title('After Transformation')
plt.show()

# %%
labels = ['Before Transformation','After Transformation']
sns.distplot(sd['YearsExperience'], bins = 15, kde = True)
sns.distplot(np.log(sd['YearsExperience']), bins = 15, kde = True)
plt.legend(labels)
plt.show()

# %% [markdown]
# **How long transformation affects the data and it scales the values down**

# %%
smf.qqplot(np.log(sd['YearsExperience']), line = 'r')
plt.title('No transformation')
smf.qqplot(np.sqrt(sd['YearsExperience']), line = 'r')
plt.title('Log transformation')
smf.qqplot(np.sqrt(sd['YearsExperience']), line = 'r')
plt.title('Square root transformation')
smf.qqplot(np.cbrt(sd['YearsExperience']), line = 'r')
plt.title('Cube root transformation')
plt.show()

# %%
labels = ['Before Transformation','After Transformation']
sns.distplot(sd['Salary'], bins = 7, kde = True)
sns.displot(np.log(sd['Salary']), bins = 7, kde = True)
plt.title('After Transformation')
plt.show()

# %%
smf.qqplot(sd['Salary'], line = 'r')
plt.title('No transformation')
smf.qqplot(np.log(sd['Salary']), line = 'r')
plt.title('Log transformation')
smf.qqplot(np.sqrt(sd['Salary']), line = 'r')
plt.title('Square root transformation')
smf.qqplot(np.cbrt(sd['Salary']), line = 'r')
plt.title('Cube root transformation')
plt.show()

# %% [markdown]
# **We only perform any data transformation when the data is skewed or not normal distribution N(0,1)**

# %%
import statsmodels.formula.api as sm
model = sm.ols('Salary~YearsExperience', data = sd).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           1.14e-20
# Time:                        16:09:22   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ** The R-squared and Adjusted R-squared scores are above 0.85.(It is a thumb rule to consider Adjusted R-squared to be greater than 0.8 for a good model for prediction)**

# %% [markdown]
# **F-statitics is quite high as well and yes desire it to be higher, but log-likelihood is quite very low far away from 0 and AIC and BIC score are much higher for this model**

# %%
model1 = sm.ols('np.sqrt(Salary)~np.sqrt(YearsExperience)', data = sd).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        np.sqrt(Salary)   R-squared:                       0.942
# Model:                            OLS   Adj. R-squared:                  0.940
# Method:                 Least Squares   F-statistic:                     454.3
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           7.58e-19
# Time:                        16:10:28   Log-Likelihood:                -116.52
# No. Observations:                  30   AIC:                             237.0
# Df Residuals:                      28   BIC:                             239.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ** The R-squared and Adjusted R-squared scores are above 0.85. but its has gotten less than previous model. (It is a thumb rule to consider Adjusted R-squared to be greater than 0.8 for a good model for prediction)**

# %% [markdown]
# **F-statitics has gotten a little lower for this model than previous, but log-likelihood got better than before close to 0 higher than previous model and AIC and BIC score are now much better for this model**

# %%
model2 = sm.ols('np.cbrt(Salary)~np.cbrt(YearsExperience)', data = sd).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        np.cbrt(Salary)   R-squared:                       0.932
# Model:                            OLS   Adj. R-squared:                  0.930
# Method:                 Least Squares   F-statistic:                     386.5
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           6.37e-18
# Time:                        16:11:38   Log-Likelihood:                -50.589
# No. Observations:                  30   AIC:                             105.2
# Df Residuals:                      28   BIC:                             108.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
model3 = sm.ols('np.log(Salary)~np.log(YearsExperience)', data = sd).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         np.log(Salary)   R-squared:                       0.905
# Model:                            OLS   Adj. R-squared:                  0.902
# Method:                 Least Squares   F-statistic:                     267.4
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           7.40e-16
# Time:                        16:14:23   Log-Likelihood:                 23.209
# No. Observations:                  30   AIC:                            -42.42
# Df Residuals:                      28   BIC:                            -39.61
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# ...

# %%
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %% [markdown]
# **Here, (Intercept) Beta0 value = 25792.20 & (YearsExperience) Beta1 value = 9449.96**

# %% [markdown]
# **Hypothesis testing of X variable by finding test_statistics and P_values for Beta1 i.e if (P_value < α=0.05 ; Reject Null)**

# %% [markdown]
# ** Null Hypothesis as Beta1=0 (No Slope) and Alternate Hypthesis as Beta1≠0 (Some or significant Slope)**

# %%
print(model.tvalues,'\n',model.pvalues)
# Out:
# Intercept          11.346940
# YearsExperience    24.950094
# dtype: float64
#  Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %% [markdown]
# **(Intercept) Beta0: tvalue=11.34 , pvalue=5.511950e-12**

# %% [markdown]
# **(daily) Beta1: tvalue=24.95, pvalue= 1.143068e-20**

# %% [markdown]
# **As (pvalue=0)<(α=0.05); Reject Null hyp. Thus, X(YearsExperience) variable has good slope and variance w.r.t Y(Salary) variable**

# %% [markdown]
#  R-squared measures the strength of the relationship between your model and the dependent variable on a 0 – 100% scale**.

# %%
model.rsquared,model.rsquared_adj
# Out:
# (0.9569566641435086, 0.9554194021486339)

# %% [markdown]
# **Deterrmination Co-efficient = rsquared value = 0.95; Very Good Fit >= 85%**

# %%
import statsmodels.api as sm
sm.qqplot(model.resid, line = 'q')
plt.title('Normal Q-Q plot of residuals of Model without any data transformation')
plt.show()

# %% [markdown]
# **The First model follows normal distribution**

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues), get_standardized_values(model.resid))
plt.title('Residual Plot for Model without any data transformation')
plt.xlabel('Standardized Fitted Values')
plt.ylabel('Standardized Residual Values')
plt.show()

# %% [markdown]
# The Model have Homoscedasciticity.
#
# The Residual(i.e Residual = Actual Value - Predicted Value) and the Fitted values do not share any Pattern.

# %%
from sklearn.metrics import mean_squared_error

# %%
model1_pred_y =np.square(model1.predict(sd['YearsExperience']))
model2_pred_y =pow(model2.predict(sd['YearsExperience']),3)
model3_pred_y =np.exp(model3.predict(sd['YearsExperience']))

# %%
model1_rmse =np.sqrt(mean_squared_error(sd['Salary'], model1_pred_y))
model2_rmse =np.sqrt(mean_squared_error(sd['Salary'], model2_pred_y))
model3_rmse =np.sqrt(mean_squared_error(sd['Salary'], model3_pred_y))
print('model=', np.sqrt(model.mse_resid),'\n' 'model1=', model1_rmse,'\n' 'model2=', model2_rmse,'\n' 'model3=', model3_rmse)
# Out:
# model= 5788.315051119395
# model1= 5960.647096174318
# model2= 6232.815455835847
# model3= 7219.716974372806

# %%
rmse = {'model': np.sqrt(model.mse_resid), 'model1': model1_rmse, 'model2': model3_rmse, 'model3' : model3_rmse}
min(rmse, key=rmse.get)
# Out:
# 'model'

# %% [markdown]
# ** Model is that Simple Linear regression model where we did not perfrom any data transformation and got the highest Adjusted R-squared value**

# %%
pred2 = pd.DataFrame()
pred2['YearsExperience'] = sd.YearsExperience
pred2['Salary'] = sd.Salary
pred2['Predicted_Salary_Hike'] = pd.DataFrame(model.predict(pred2.YearsExperience))
pred2
# Out:
#     YearsExperience    Salary  Predicted_Salary_Hike
# 0               1.1   39343.0           36187.158752
# 1               1.3   46205.0           38077.151217
# 2               1.5   37731.0           39967.143681
# 3               2.0   43525.0           44692.124842
# 4               2.2   39891.0           46582.117306
# 5               2.9   56642.0           53197.090931
# 6               3.0   60150.0           54142.087163
# 7               3.2   54445.0           56032.079627
# 8               3.2   64445.0           56032.079627
# 9               3.7   57189.0           60757.060788
# 10              3.9   63218.0           62647.053252
# 11              4.0   55794.0           63592.049484
# 12              4.0   56957.0           63592.049484
# 13              4.1   57081.0           64537.045717
# 14              4.5   61111.0           68317.030645
# 15              4.9   67938.0           72097.015574
# 16              5.1   66029.0           73987.008038
# ...
